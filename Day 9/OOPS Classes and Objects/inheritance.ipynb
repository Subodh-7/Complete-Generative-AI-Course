# %% [markdown]
# # Inheritance in Python
#
# Inheritance is a fundamental concept in Object-Oriented Programming (OOP) that allows a class to inherit attributes and methods from another class. This lesson covers single inheritance and multiple inheritance, demonstrating how to create and use them in Python.

# %%
## Inheritance (Single Inheritance)
## Parent class
class Car:
    def __init__(self, windows,doors,enginetype):
        self.windows = windows
        self.doors = doors
        self.enginetype = enginetype
    
    def drive(self):
        print(f"Driving a car with {self.windows} windows, {self.doors} doors, and {self.enginetype} engine.")

# %%
car1 = Car(4, 5, "Petrol")
print(car1.drive)
car1.drive()
# Out:
# <bound method Car.drive of <__main__.Car object at 0x000002CE6AD19D10>>
# Driving a car with 4 windows, 5 doors, and Petrol engine.

# %%
class Tesla(Car):
    def __init__(self,windows,doors,enginetype,is_selfdriving):
        super().__init__(windows,doors,enginetype)
        self.is_selfdriving = is_selfdriving
    def selfdriving(self):
        print(f"Tesla is self driving: {self.is_selfdriving}")

# %%
tesla1=Tesla(4, 5, "Electric", True)
print(tesla1.selfdriving)
tesla1.selfdriving()
# Out:
# <bound method Tesla.selfdriving of <__main__.Tesla object at 0x000002CE6AE38050>>
# Tesla is self driving: True

# %%
tesla1=Tesla(4, 5, "Electric", True)
print(tesla1.drive)
tesla1.drive()
# Out:
# <bound method Car.drive of <__main__.Tesla object at 0x000002CE6AE382D0>>
# Driving a car with 4 windows, 5 doors, and Electric engine.

# %%
## Multiple Inheritance
## When a class for more than one base class.
#Base class 1

class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        print("Subclass must implement this method")

# Base class 2
class Pet:
    def __init__(self,owner):
        self.owner = owner

# Derived class
class Dog(Animal,Pet):
    def __init__(self, name, owner):
        Animal.__init__(self, name)
        Pet.__init__(self, owner)

    def speak(self):
        return f"{self.name} says woof"

# Create object
dog = Dog("Buddy", "Subodh")
print(dog.speak())
print(f"{dog.name} is owned by {dog.owner}")
# Out:
# Buddy says woof
# Buddy is owned by Subodh
