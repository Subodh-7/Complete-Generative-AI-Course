# %% [markdown]
# Variables

# %%
a=100
print(a)
# Out:
# 100

# %%
##Declaring and Assigning Variables

age=32
height=6.1
name="Subodh"
is_student=True

##printing the variables
print("Age:", age)
print("Height:", height)
print("Name:", name)
# Out:
# Age: 32
# Height: 6.1
# Name: Subodh

# %%
##Naming Conventions
##Variable names should be descriptive.
##They must start with a letter or an underscore '_' and contains, numbers and underscores.
##Variable names are case sensitive.

##valid variable names

firt_name="Subodh"
last_name="Raut"

# %%
##Invalid Varaible Names
##2age=30
##first-name="Subodh"
##@name="Subodh"
# Out:
#   Cell In[6], line 4
#     @name="Subodh"
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
##case sensitivity of variable names
name="Subodh"
Name="Raut"

name==Name
# Out:
# False

# %%
##Understanding Variable Types
##Python is a dynamically typed language, which means you don't have to declare the type of a variable when you create one.
# The type is inferred from the value assigned to it.
##Type of variable is determined at runtime.

age=25 #int
height=6.1 #float
name="Subodh" #str
is_student=True #bool

print(type(age))
print(type(height))
print(type(name))
print(type(is_student))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
##Type checking and Type conversion
type(height) #float
# Out:
# float

# %%
age=25
print(type(age)) #int

#Type conversion
age_str=str(age)
print(age_str)
print(type(age_str)) #str
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
age='25'
int(age) #int
print(type(int(age))) #int
# Out:
# <class 'int'>

# %%
name="Subodh"
int(name) #Error: invalid literal for int() with base 10: 'Subodh'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 name="Subodh"
# ----> 2 int(name) #Error: invalid literal for int() with base 10: 'Subodh'
#
# ValueError: invalid literal for int() with base 10: 'Subodh'

# %%
height=5.11
type(height) #float
# Out:
# float

# %%
int(height) #int
# Out:
# 5

# %%
float(height) #float
# Out:
# 5.1

# %%
float(int(height)) #float
# Out:
# 5.0

# %%
##Dynamic Typing
##Python allows you to change the type of a variable to change as the program executes.
var=10
print(var, type(var))

var="Hello"
print(var, type(var))

var=3.14
print(var, type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
##Input

age=input("What is the age")
print(age, type(age)) #str
# Out:
# 31 <class 'str'>

# %%
##Simple Calculator
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

sum = num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2

print("Sum:", sum)
print("Difference:", difference)
print("Product:", product)
print("Quotient:", quotient)
