# %%
## Operators in Python
## Operators are special symbols that perform operations on variables and values. 
# In Python, we have several types of operators, including:
#Arithmetic Operators: Used for mathematical operations like addition, subtraction, 
# multiplication, etc.

##Comparison Operators: Used to compare values and return a boolean result.
# Equal to, Not equal to, Greater than, Less than, Greater than or equal to, 
# Less than or equal to.

##Logical Operators: Used to combine conditional statements.
# And, Or, Not.

# %%
##Arithmetic Operators
a=10
b=5

add_result=a+b ##addition
sub_result=a-b ##subtraction
mul_result=a*b ##multiplication
div_result=a/b ##division
floor_div_result=a//b ##floor division
modulus_result=a%b ##modulus

exponentiation_result=a**b ##Exponentiation

print(add_result) #15
print(sub_result) #5
print(mul_result) #50
print(div_result) #2.0
print(floor_div_result) #2
print(modulus_result) #0
print(exponentiation_result) #100000
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %%
10/5
# Out:
# 2.0

# %%
21/5
# Out:
# 4.2

# %%
21//5
# Out:
# 4

# %% [markdown]
# ### Comparison Operators

# %%
##Comparison Operators
## == Equal to
a=10
b=10
a==b
# Out:
# True

# %%
str1="Subodh"
str2="Subodh"

str1==str2
# Out:
# True

# %%
## Not Equal to !=
str1!=str2
# Out:
# False

# %%
str3="Subodh"
str4="subodh"

str3!=str4
# Out:
# True

# %%
##Greater than >
num1=45
num2=55

num1>num2
# Out:
# False

# %%
##less than <
num1<num2
# Out:
# True

# %%
##greaten than or equal to >=
number1=45
number2=45

number1>=number2
print(number1>=number2) #True
# Out:
# True

# %%
##less than or equal to <=
number1=44
number2=45

number1<=number2
print(number1<=number2) #True
# Out:
# True

# %% [markdown]
# ### Logical Operators

# %%
##AND, NOT, OR

X= True
Y= True

result = X and Y
print(result) #True

# %%
X= False
Y= True

result = X and Y
print(result) #False
# Out:
# False

# %%
##OR
X= False
Y= False

result = X or Y
print(result) #False
# Out:
# False

# %%
##OR
X= True
Y= False

result = X or Y
print(result) #True
# Out:
# True

# %%
##Not operator
X= True
not X
# Out:
# False

# %%
##Not operator
X= False
not X
# Out:
# True

# %%
## Simple Calculator using Operators
num1= float(input("Enter first number: "))
num2= float(input("Enter second number: "))

#Performing arithmetic operations
addition = num1 + num2
subtraction = num1 - num2
multiplication = num1 * num2
division = num1 / num2
floor_division = num1 // num2
modulus = num1 % num2
exponentiation = num1 ** num2

#Diplaying the results
print("Addition: ", addition)
print("Subtraction: ", subtraction)
print("Multiplication: ", multiplication)
print("Division: ", division)
print("Floor Division: ", floor_division)
print("Modulus: ", modulus)
print("Exponentiation: ", exponentiation)
# Out:
# Addition:  11.0
# Subtraction:  3.0
# Multiplication:  28.0
# Division:  1.75
# Floor Division:  1.0
# Modulus:  3.0
# Exponentiation:  2401.0
