# %% [markdown]
# DataTypes

# %%
## Datatypes
## Datatypes are classifications of data that determine the type of value a variable can hold.

# %%
## Integer example
age=35
type(age) #int
# Out:
# int

# %%
##floating point datatype
height=5.11
print(height)
print(type(height)) #float
# Out:
# 5.11
# <class 'float'>

# %%
##string datatype example
name="Subodh"
print(name)
print(type(name)) #str
# Out:
# Subodh
# <class 'str'>

# %%
##boolean datatype example
is_True = True
type(is_True) #bool
# Out:
# bool

# %%
bool()
# Out:
# False

# %%
a=10
class Foo:
    b=5

dummyFoo = Foo()
print('id of dummyFoo:', id(dummyFoo))
# Out:
# id of dummyFoo: 1561960035536

# %%
a=10
b=10

type(a==b) #bool
# Out:
# bool

# %%
##common errors
result="Hello" + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 ##common errors
# ----> 2 result="Hello" + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
result="Hello" + str(5)
print(result)
# Out:
# Hello5
